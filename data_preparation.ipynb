# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\hoang\appdata\local\programs\python\python310\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\hoang\appdata\local\programs\python\python310\lib\site-packages (from opencv-python) (1.24.3)
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os, cv2, time, uuid

IMAGE_PATH = "Tensorflow/workspace/images/collectedImages"

labels = ["Nue", "Divine_Dog", "Mahoraga", "Idle_Death_Gamble", "Unlimited_Void", "Malevolent_Shrine"]
number_imgs = 15

# %%
for label in labels:
    # !mkdir {"Tensorflow\workspace\images\collectedImages\\" + label}
    cap = cv2.VideoCapture(0)
    print ("Collecting images for {}".format(label))
    time.sleep(5)
    for imgnum in range(number_imgs):
        ret, frame = cap.read()
        imagename = os.path.join(
            IMAGE_PATH,
            label,
            label + '.' + "{}.jpg".format(str(uuid.uuid1()))
        )
        cv2.imwrite(imagename, frame)
        cv2.imshow("frame", frame)
        time.sleep(2)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    cap.release()
# Out:
# You can do it!!!
